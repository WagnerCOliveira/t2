# %% [markdown]
# ## 1. Há departamentos ou gêneros que apresentam taxas de admissão ou rejeição desproporcionalmente altas ou baixas?
#
# * Sim, seguem as seguintes analises para validar.
# Nos departamentos A e B é onde está a maior desporpocinalidade onde os homens apresentam a maior taxa de admissão e também de rejeição, sendo que a maior variação na admissão chega há 90% e na rejeição 92% no departamento B.
#
# * Nos departamentos D e F é onde estão as menores variações, sendo o genero Masculino que tem a menor desproporcionalidade, no departamento D a variação de admissão chega 2%, já variação da rejeição de 5% no departamento F.

# %% [markdown]
# ## 2. Há equilíbrio na distribuição de gêneros nos departamentos?
#
# * Não há um equilibrio quando a analise é agregada, existe uma superioridade para o genero Masculino com uma diferença real de 24.16 %, levando em relação deferença entre o total de Homens e o total de mulheres nos departamentos.
#
# * Quando a analise é desagregada existe uma relação inversa com relação a distribuição entre os departamentos, levando em consideração as taxas de admissao.

# %% [markdown]
# ## 3. Como os padrões de admissão diferem entre os departamentos e gêneros?
#
# * Eles diferem de forma inversamente porporcinal. Nos cursos A, B o gênero masculino é o mais aceito o feminino é o mais rejeitado e nos cursos C, E, F o genero feminino é mais aceito e o masculino mais rejeitado.

# %% [markdown]
# ## 4. Existe um viés aparente contra algum gênero?
#
# * há um viés contra o gênero feminíno, sugerindo que os gênero opósto é melhor avaliado pela quantidade de incrições, sem levar em consideração a analise desagregada por admissão nos departamentos.

# %% [markdown]
# ## 5. Há departamentos mais favoráveis a um gênero específico?
#
# Sim.
#
# * Os departamentos A, B são mais favoraveis ao gênero Masculino
#
# * Os departamentos C, E, F são mais favoraveis ao gênero feminino.
#
# * O departamento D tem uma diferença em torno de 2% para o gênero masculino favorecendo uma igualdade.

# %% [markdown]
# ## 6. Quais departamentos são mais competitivos e como isso afeta os gêneros?
#
# * Os departamentos C, D, E, F são mais competitivos, com tudo o F é o mais competitivo, há presença do gênero feminino é maior nos cursos C, E, F onde a competição é mais acirada.
#
# * Nos departamentos A, B é de esmagadora presença do genero maculino onde a competitividade é menor e o departamento A tem a menor competitidade.

# %% [markdown]
# ## 7. Como as conclusões mudam ao desagregar os dados por departamento?
#
# * Elas evidenciam o grau de competitividade, e tamanho do esforço para ser aceito(a) em determinados departamentos, e também muda o vies de que o gênero masculino é melhor pela quantidade de incrições ser maior. O desagregamento ds dados mostram que o gênero feminino é mais aceitos em cursos cujo a competição é mais acirada.

# %% [markdown]
# ## 8. Justifique o viés de gênero nas admissões de pós-graduação de Berkeley.
#
# * Na analise inicial sugerisse um vies contra as mulheres, a analise dos dados mais a fundo mostrou que o sistema de admissão em quase todas as formas é justo, e foi descoberto um pequeno viés favoravel as mulheres em linhas gerais.
